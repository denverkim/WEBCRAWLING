# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/WEBCRAWLING/blob/main/LAB6_EXERCISE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")

# %%
soup = BeautifulSoup(page.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
soup.title
soup.p.string
soup.p.text
soup.p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %%
soup.find('p')
# Out:
# <p>Here is some simple content for this page.</p>

# %%
page = requests.get('http://dataquestio.github.io/web-scraping-pages/ids_and_classes.html')
soup = BeautifulSoup(page.content)
print(soup.prettify())
soup.p
# Out:
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     First paragraph.
#    </p>
#    <p class="inner-text">
#     Second paragraph.
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     First outer paragraph.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     Second outer paragraph.
#    </b>
#   </p>
#  </body>
# </html>
# <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>

# %%
soup.find_all('p')
# Out:
# <p class="outer-text">
# <b>
#                 Second outer paragraph.
#             </b>
# </p>
