# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/WEBCRAWLING/blob/main/LAB11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome. The sky is pinkish-blue. You shouldn't eat cardboard"""
sent=sent_tokenize(text)
print(sent)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]

# %%
sent[1]
# Out:
# 'The weather is great, and city is awesome.'

# %%
from nltk.tokenize import word_tokenize
words=word_tokenize(text)
print(words)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(words)
fdist
# Out:
# FreqDist({'is': 3, ',': 2, 'The': 2, '.': 2, 'Hello': 1, 'Mr.': 1, 'Smith': 1, 'how': 1, 'are': 1, 'you': 1, ...})

# %%
fdist.most_common(2) #상위2개
# Out:
# [('is', 3), (',', 2)]

# %%
# 다른 방법
from collections import Counter
word_freq = Counter(words)
word_freq
# Out:
# Counter({'Hello': 1,
#          'Mr.': 1,
#          'Smith': 1,
#          ',': 2,
#          'how': 1,
#          'are': 1,
#          'you': 1,
#          'doing': 1,
#          'today': 1,
#          '?': 1,
#          'The': 2,
#          'weather': 1,
#          'is': 3,
#          'great': 1,
#          'and': 1,
#          'city': 1,
#          'awesome': 1,
#          '.': 2,
#          'sky': 1,
#          'pinkish-blue': 1,
#          'You': 1,
#          'should': 1,
#          "n't": 1,
#          'eat': 1,
#          'cardboard': 1})

# %%
import matplotlib.pyplot as plt

fdist.plot(30,cumulative=False)
#or fdist.plot(30)
plt.show()

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

stop_words=set(stopwords.words("english"))
print(stop_words)
len(stop_words)
# Out:
# {'again', "they've", 'itself', 'shan', 'should', 'about', 'them', 'she', 'mightn', 'having', "they're", 'whom', "won't", 'further', 'don', 'there', "it'd", "couldn't", 'but', 'before', 'did', 'your', 'that', 'being', 'these', 'while', "mightn't", 'had', 'for', 'once', 'does', 'we', 'not', "isn't", "wouldn't", 'if', 'in', 'its', 'no', 'aren', "you'll", "i'm", 'down', 'few', 'so', 'this', 'up', "we'll", 'doing', 'below', 'a', 've', 'wouldn', 'couldn', 'at', 'it', "wasn't", 'to', 'won', 'same', 'why', "hasn't", 'herself', 'were', "she'd", "should've", "aren't", 'can', 'of', 'the', "you're", 'are', "hadn't", 'her', 'will', 'mustn', 'on', 'or', "don't", 'ma', 'yours', 'by', 'how', 'all', "i've", 'under', 'been', 'as', 'themselves', 'those', "we'd", "i'll", "haven't", 'than', 'until', 'yourselves', "it's", 'here', 'some', 'because', 'any', 'didn', 'do', 'theirs', 't', "weren't", "she's", 'with', "i'd", "you've", 'above', 'y', 'only', 'hadn', 'ain', 'ourselves', 'over', 'and', 'more', "it'l
# ...

# %%
stop_words = list(stop_words)

# %%
stop_words.append('The')
stop_words.append('You')

# %%
stop_words
# Out:
# ['again',
#  "they've",
#  'itself',
#  'shan',
#  'should',
#  'about',
#  'them',
#  'she',
#  'mightn',
#  'having',
#  "they're",
#  'whom',
#  "won't",
#  'further',
#  'don',
#  'there',
#  "it'd",
#  "couldn't",
#  'but',
#  'before',
#  'did',
#  'your',
#  'that',
#  'being',
#  'these',
#  'while',
#  "mightn't",
#  'had',
#  'for',
#  'once',
#  'does',
#  'we',
#  'not',
#  "isn't",
#  "wouldn't",
#  'if',
#  'in',
#  'its',
#  'no',
#  'aren',
#  "you'll",
#  "i'm",
#  'down',
#  'few',
#  'so',
#  'this',
#  'up',
#  "we'll",
#  'doing',
#  'below',
#  'a',
#  've',
#  'wouldn',
#  'couldn',
#  'at',
#  'it',
#  "wasn't",
#  'to',
#  'won',
#  'same',
#  'why',
#  "hasn't",
#  'herself',
#  'were',
#  "she'd",
#  "should've",
#  "aren't",
#  'can',
#  'of',
#  'the',
#  "you're",
#  'are',
#  "hadn't",
#  'her',
#  'will',
#  'mustn',
#  'on',
#  'or',
#  "don't",
#  'ma',
#  'yours',
#  'by',
#  'how',
#  'all',
#  "i've",
#  'under',
#  'been',
#  'as',
# ...

# %%
filter_words=[w for w in words if w not in stop_words]

# %%
filter_words
# Out:
# ['Hello',
#  'Mr.',
#  'Smith',
#  ',',
#  'today',
#  '?',
#  'weather',
#  'great',
#  ',',
#  'city',
#  'awesome',
#  '.',
#  'sky',
#  'pinkish-blue',
#  '.',
#  "n't",
#  'eat',
#  'cardboard']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
ps.stem('flying')
# Out:
# 'fli'

# %%
stem_words=[ps.stem(word) for word in filter_words]

# %%
stem_words
# Out:
# ['hello',
#  'mr.',
#  'smith',
#  ',',
#  'today',
#  '?',
#  'weather',
#  'great',
#  ',',
#  'citi',
#  'awesom',
#  '.',
#  'sky',
#  'pinkish-blu',
#  '.',
#  "n't",
#  'eat',
#  'cardboard']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()
lem.lemmatize('flying', 'v')
# Out:
# 'fly'

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
nltk.pos_tag(words)
# Out:
# [('Hello', 'NNP'),
#  ('Mr.', 'NNP'),
#  ('Smith', 'NNP'),
#  (',', ','),
#  ('how', 'WRB'),
#  ('are', 'VBP'),
#  ('you', 'PRP'),
#  ('doing', 'VBG'),
#  ('today', 'NN'),
#  ('?', '.'),
#  ('The', 'DT'),
#  ('weather', 'NN'),
#  ('is', 'VBZ'),
#  ('great', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('city', 'NN'),
#  ('is', 'VBZ'),
#  ('awesome', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('sky', 'NN'),
#  ('is', 'VBZ'),
#  ('pinkish-blue', 'JJ'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('should', 'MD'),
#  ("n't", 'RB'),
#  ('eat', 'VB'),
#  ('cardboard', 'NN')]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
nopunc_words = [word for word in stem_words if word not in string.punctuation]

# %%
nopunc_words
# Out:
# ['hello',
#  'mr.',
#  'smith',
#  'today',
#  'weather',
#  'great',
#  'citi',
#  'awesom',
#  'sky',
#  'pinkish-blu',
#  "n't",
#  'eat',
#  'cardboard']

# %%
from wordcloud import WordCloud, STOPWORDS

wordcloud = WordCloud().generate(text)

fig=plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear') #Make the displayed image appear more smoothly.
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
wordcloud = WordCloud(max_font_size=50, #글씨 크기
                      max_words=100, #최대 단어수
                      background_color="white", #배경색
                      stopwords=STOPWORDS, #불용어
                      colormap="Accent_r").generate(text) #칼라맵
plt.imshow(wordcloud, interpolation="bilinear") #Make the displayed image appear more smoothly.
plt.axis("off")
plt.show()

# %%
words = word_tokenize(text)

# 전처리 과정 중간에 넣고

fdist = FreqDist(words)
wordcloud = WordCloud().generate_from_frequencies(fdist)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import re
import string
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
from nltk.stem import PorterStemmer
ps = PorterStemmer()
text="Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."
def clean_text(text):
    text = "".join([char.lower() for char in text if char not in string.punctuation])
    tokens = re.split('\W+', text) # word_tokenize(text)와 같음
    text = [ps.stem(word) for word in tokens if word not in stop_words]
    return text
clean_text(text)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# /tmp/ipykernel_1084/582525849.py:10: SyntaxWarning: invalid escape sequence '\W'
#   tokens = re.split('\W+', text) # word_tokenize(text)와 같음
# ['hello',
#  'mr',
#  'smith',
#  'today',
#  'weather',
#  'great',
#  'citi',
#  'awesom',
#  'sky',
#  'pinkishblu',
#  'shouldnt',
#  'eat',
#  'cardboard']

# %%
# 오바마 연설문 워드 클라우드 만들기
import requests

page = requests.get('http://programminghistorian.github.io/ph-submissions/assets/basic-text-processing-in-r/sotu_text/236.txt')

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.text)
text = soup.get_text()

# %%
from wordcloud import WordCloud, STOPWORDS
wordcloud = WordCloud(max_font_size=50, #글씨 크기
                      max_words=100, #최대 단어수
                      background_color="white", #배경색
                      stopwords=STOPWORDS, #불용어
                      colormap="viridis").generate(text) #칼라맵
plt.imshow(wordcloud, interpolation="bilinear") #Make the displayed image appear more smoothly.
plt.axis("off")
plt.show()
